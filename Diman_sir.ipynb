# %% [markdown]
# <a href="https://colab.research.google.com/github/NandiniBasdwar7/concise/blob/main/Diman_sir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.read_csv('/content/index.csv')

# %%
df1
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 1128  2024-07-31  2024-07-31 20:53:35.077      card  ANON-0000-0000-0443
# 1129  2024-07-31  2024-07-31 20:59:25.013      card  ANON-0000-0000-0040
# 1130  2024-07-31  2024-07-31 21:26:26.000      card  ANON-0000-0000-0444
# 1131  2024-07-31  2024-07-31 21:54:11.824      card  ANON-0000-0000-0445
# 1132  2024-07-31  2024-07-31 21:55:16.570      card  ANON-0000-0000-0446
#
#       money          coffee_name
# 0     38.70                Latte
# ...

# %%
df1.columns.tolist()
# Out:
# ['date', 'datetime', 'cash_type', 'card', 'money', 'coffee_name']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1133 non-null   datetime64[ns]
#  1   datetime     1133 non-null   datetime64[ns]
#  2   cash_type    1133 non-null   object
#  3   card         1133 non-null   object
#  4   money        1133 non-null   int64
#  5   coffee_name  1133 non-null   object
#  6   month        1133 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 62.1+ KB

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1['date']=pd.to_datetime(df1['date'])

# %%
df1['date'].tail()
# Out:
# 1128   2024-07-31
# 1129   2024-07-31
# 1130   2024-07-31
# 1131   2024-07-31
# 1132   2024-07-31
# Name: date, dtype: datetime64[ns]

# %%
df1['datetime']=pd.to_datetime(df1['datetime'])

# %%
df1['card']=df1['card'].fillna('unknown')

# %%
df1['card']
# Out:
# 0       ANON-0000-0000-0001
# 1       ANON-0000-0000-0002
# 2       ANON-0000-0000-0002
# 3       ANON-0000-0000-0003
# 4       ANON-0000-0000-0004
#                ...
# 1128    ANON-0000-0000-0443
# 1129    ANON-0000-0000-0040
# 1130    ANON-0000-0000-0444
# 1131    ANON-0000-0000-0445
# 1132    ANON-0000-0000-0446
# Name: card, Length: 1133, dtype: object

# %%
df1.isna().sum()
# Out:
# date           0
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# dtype: int64

# %%
#which 'coffee_name' highest sale?
df1['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with Milk    268
# Latte                  243
# Cappuccino             196
# Americano              169
# Cortado                 99
# Hot Chocolate           74
# Espresso                49
# Cocoa                   35
# Name: count, dtype: int64

# %%
#which coffee type highest total revenue?
df1.groupby('coffee_name')['money'].sum()
# Out:
# coffee_name
# Americano              4530
# Americano with Milk    8390
# Cappuccino             7201
# Cocoa                  1273
# Cortado                2672
# Espresso               1099
# Hot Chocolate          2729
# Latte                  8848
# Name: money, dtype: int64

# %%
#how many unique customers bought coffee in march 2024?
march_df=df1[df1['date'].dt.month==3]
march_df['card'].nunique()
# Out:
# 90

# %%
#i want find out month wise which cofee sale most?
df1['month']=df1['date'].dt.month_name()
df1.groupby('month')['coffee_name'].value_counts().reset_index()
# Out:
#     month          coffee_name  count
# 0   April           Cappuccino     43
# 1   April  Americano with Milk     42
# 2   April            Americano     35
# 3   April                Latte     31
# 4   April              Cortado     19
# 5   April        Hot Chocolate     13
# 6   April             Espresso      7
# 7   April                Cocoa      6
# 8    July  Americano with Milk     65
# 9    July                Latte     56
# 10   July            Americano     36
# 11   July           Cappuccino     32
# 12   July              Cortado     14
# 13   July             Espresso     14
# 14   July        Hot Chocolate     11
# 15   July                Cocoa      9
# 16   June  Americano with Milk     69
# 17   June                Latte     50
# 18   June           Cappuccino     46
# 19   June              Cortado     19
# 20   June            Americano     14
# 21   June        Hot Chocolate     14
# 22   June             Espresso     10
# 23   June                Cocoa      5
# ...

# %%
#how manypayments were made using cards?
df1['cash_type'].value_counts().reset_index()
# Out:
#   cash_type  count
# 0      card   1044
# 1      cash     89

# %%
#find total money earned?


df1['money']=df1['money'].astype(int)

df1['money'].sum()
# Out:
# np.int64(36742)

# %%
df1
# Out:
#            date                datetime cash_type                 card  money  \
# 0    2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001     38
# 1    2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002     38
# 2    2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002     38
# 3    2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003     28
# 4    2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004     38
# ...         ...                     ...       ...                  ...    ...
# 1128 2024-07-31 2024-07-31 20:53:35.077      card  ANON-0000-0000-0443     23
# 1129 2024-07-31 2024-07-31 20:59:25.013      card  ANON-0000-0000-0040     27
# 1130 2024-07-31 2024-07-31 21:26:26.000      card  ANON-0000-0000-0444     32
# 1131 2024-07-31 2024-07-31 21:54:11.824      card  ANON-0000-0000-0445     32
# 1132 2024-07-31 2024-07-31 21:55:16.570      card  ANON-0000-0000-0446     32
#
#               coffee_name
# ...

# %%
df2=pd.read_csv('/content/world food production.csv')

# %%
df2
# Out:
#             Entity  Year  Maize Production (tonnes)  \
# 0      Afghanistan  1961                   700000.0
# 1      Afghanistan  1962                   700000.0
# 2      Afghanistan  1963                   713000.0
# 3      Afghanistan  1964                   720000.0
# 4      Afghanistan  1965                   720000.0
# ...            ...   ...                        ...
# 11907     Zimbabwe  2017                  1532572.0
# 11908     Zimbabwe  2018                  1560100.0
# 11909     Zimbabwe  2019                   773976.0
# 11910     Zimbabwe  2020                  1202347.0
# 11911     Zimbabwe  2021                  1469664.0
#
#        Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0                       319000.00               7.467702e+06
# 1                       319000.00               7.420515e+06
# 2                       319000.00               8.479074e+06
# 3                       380000.00               9.113779e+06
# ...

# %%
df2.columns.tolist()
# Out:
# ['Entity',
#  'Year',
#  'Maize Production (tonnes)',
#  'Rice  Production ( tonnes)',
#  'Yams  Production (tonnes)',
#  'Wheat Production (tonnes)',
#  'Tomatoes Production (tonnes)',
#  'Tea  Production ( tonnes )',
#  'Sweet potatoes  Production (tonnes)',
#  'Sunflower seed  Production (tonnes)',
#  'Sugar cane Production (tonnes)',
#  'Soybeans  Production (tonnes)',
#  'Rye  Production (tonnes)',
#  'Potatoes  Production (tonnes)',
#  'Oranges  Production (tonnes)',
#  'Peas, dry Production ( tonnes)',
#  'Palm oil  Production (tonnes)',
#  'Grapes  Production (tonnes)',
#  'Coffee, green Production ( tonnes)',
#  'Cocoa beans Production (tonnes)',
#  'Meat, chicken  Production (tonnes)',
#  'Bananas  Production ( tonnes)',
#  'Avocados Production (tonnes)',
#  'Apples Production (tonnes)']

# %%
df2.shape
# Out:
# (11912, 24)

# %%
df2.isna().sum()
# Out:
# Entity                                 0
# Year                                   0
# Maize Production (tonnes)              0
# Rice  Production ( tonnes)             0
# Yams  Production (tonnes)              0
# Wheat Production (tonnes)              0
# Tomatoes Production (tonnes)           0
# Tea  Production ( tonnes )             0
# Sweet potatoes  Production (tonnes)    0
# Sunflower seed  Production (tonnes)    0
# Sugar cane Production (tonnes)         0
# Soybeans  Production (tonnes)          0
# Rye  Production (tonnes)               0
# Potatoes  Production (tonnes)          0
# Oranges  Production (tonnes)           0
# Peas, dry Production ( tonnes)         0
# Palm oil  Production (tonnes)          0
# Grapes  Production (tonnes)            0
# Coffee, green Production ( tonnes)     0
# Cocoa beans Production (tonnes)        0
# Meat, chicken  Production (tonnes)     0
# Bananas  Production ( tonnes)          0
# Avocados Production (tonnes)           0
# ...

# %%
import numpy as np # numarical calculation
import matplotlib.pyplot as plt # basic vizualization
import seaborn as sns # attractive graph
import warnings
warnings.filterwarnings('ignore')

# %%
df2.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_3e8e5_row0_col1, #T_3e8e5_row0_col2, #T_3e8e5_row0_col3, #T_3e8e5_row0_col6, #T_3e8e5_row0_col7, #T_3e8e5_row0_col9, #T_3e8e5_row0_col10, #T_3e8e5_row0_col11, #T_3e8e5_row0_col14, #T_3e8e5_row0_col15, #T_3e8e5_row0_col17, #T_3e8e5_row0_col18, #T_3e8e5_row0_col19, #T_3e8e5_row0_col20, #T_3e8e5_row0_col21, #T_3e8e5_row0_col23, #T_3e8e5_row1_col2, #T_3e8e5_row1_col3, #T_3e8e5_row1_col4, #T_3e8e5_row1_col10, #T_3e8e5_row1_col12, #T_3e8e5_row1_col13, #T_3e8e5_row1_col14, #T_3e8e5_row1_col16, #T_3e8e5_row1_col17, #T_3e8e5_row1_col23, #T_3e8e5_row2_col3, #T_3e8e5_row2_col5, #T_3e8e5_row2_col10, #T_3e8e5_row2_col14, #T_3e8e5_row2_col17, #T_3e8e5_row2_col22, #T_3e8e5_row2_col23, #T_3e8e5_row3_col10, #T_3e8e5_row4_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3e8e5_row0_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3e8e5_row0_col5, #T_3e8e5_row1_col5 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# ...

# %%
df2.describe()
# Out:
#                Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# count  11912.000000               1.191200e+04                1.191200e+04
# mean    1992.115346               1.926434e+07                2.254542e+07
# std       17.606091               7.028022e+07                7.749779e+07
# min     1961.000000               0.000000e+00                0.000000e+00
# 25%     1977.000000               2.379300e+04                3.902475e+04
# 50%     1993.000000               4.000490e+05                4.543745e+05
# 75%     2007.000000               4.979875e+06                4.440542e+06
# max     2021.000000               1.210235e+09                7.872939e+08
#
#        Yams  Production (tonnes)  Wheat Production (tonnes)  \
# count               1.191200e+04               1.191200e+04
# mean                2.744973e+06               2.365684e+07
# std                 8.787786e+06               6.177899e+07
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11912 entries, 0 to 11911
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Entity                               11912 non-null  object
#  1   Year                                 11912 non-null  int64
#  2   Maize Production (tonnes)            11912 non-null  float64
#  3   Rice  Production ( tonnes)           11912 non-null  float64
#  4   Yams  Production (tonnes)            11912 non-null  float64
#  5   Wheat Production (tonnes)            11912 non-null  float64
#  6   Tomatoes Production (tonnes)         11912 non-null  float64
#  7   Tea  Production ( tonnes )           11912 non-null  float64
#  8   Sweet potatoes  Production (tonnes)  11912 non-null  float64
#  9   Sunflower seed  Production (tonnes)  11912 non-null  float64
#  10  Sugar cane Production (tonnes)       11912 non-null  float64
# ...

# %%
df2.columns = df2.columns.str.strip()

# %%
df2['Total Production (tonnes)']=df2[['Maize Production (tonnes)',  'Rice  Production ( tonnes)']].sum(axis=1)
