# %% [markdown]
# <a href="https://colab.research.google.com/github/NandiniBasdwar7/concise/blob/main/DAY12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Merge weather and sales data to prepare for analysis
import pandas as pd
sales={
    'Date':['2023-01-01','2023-01-01','2023-01-02','2023-01-02','2023-01-03'],
    'Location':['Store A','Store B','Store A','Store B','Store A'],
    'Product': ['Item X', 'Item Y', 'Item X', 'Item Z', 'Item Y'],
    'Sales': [100, 150, 120, 200, 180]
}
df_sales = pd.DataFrame(sales)

weather={
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
    'Location': ['Store A', 'Store A', 'Store A', 'Store B'],
    'Temperature_C': [5, 6, 7, 8],
    'Precipitation_mm': [10, 5, 2, 0],
    'Humidity_%': [80, 75, 70, 60]
}
weather = pd.DataFrame(weather)
merged_df = pd.merge(df_sales, weather, on=['Date', 'Location'], how='inner')
merged_df
# Out:
#          Date Location Product  Sales  Temperature_C  Precipitation_mm  \
# 0  2023-01-01  Store A  Item X    100              5                10
# 1  2023-01-02  Store A  Item X    120              6                 5
# 2  2023-01-03  Store A  Item Y    180              7                 2
#
#    Humidity_%
# 0          80
# 1          75
# 2          70

# %%
import pandas as pd
df1= pd.DataFrame({'store_id' : [1,2,3,4], 'date' : ['2025-07-13', '2025-07-14', '2025-07-15', '2025-07-16'], 'sales' : [400,350,800,650]})


df2= pd.DataFrame({'store_id' : [1,2,4,10], 'date' : ['2025-07-13', '2025-07-14', '2025-07-25', '2025-07-16'], 'temp' : [40,35,28,36]})

merged= pd.merge(df1,df2,on=['store_id','date'])
merged.plot.line(x='sales', y='temp')
# Out:
# <Axes: xlabel='sales'>

# %%
merged=pd.read_csv

# %%
# Handling mismatched data
s1=pd.Series([1,2,3,4],index=['a','b','d','e'])
s2=pd.Series([4,3,2,1],index=['a','b','c','d'])
result=s1+s2
result
# Out:
# a    5.0
# b    5.0
# c    NaN
# d    4.0
# e    NaN
# dtype: float64

# %%
#Use astype() to convert columns to the correct data type
import pandas as pd
df = pd.DataFrame({'col1': ['1', '2', '3','NAN'], 'col2': ['2023-01-01',  '02-01-2023','2023-01-02','NAN']})
#df['col1'] = df['col1'].astype(int)
df['col2'] = pd.to_datetime(df['col2'], errors='coerce') # 'coerce' turns invalid dates into NaT
df['col1']
# Out:
# 0      1
# 1      2
# 2      3
# 3    NAN
# Name: col1, dtype: object

# %%
df['col2'] = pd.to_datetime(df['col2'], format='mixed', errors='coerce')
df['col2']
# Out:
# 0   2023-01-01
# 1          NaT
# 2   2023-01-02
# 3          NaT
# Name: col2, dtype: datetime64[ns]

# %%
#df['col2']= df.dropna()  # Drop rows with any missing values
print(df['col1'])
df['col1'].fillna(0)  # Fill missing values with 0
df['col1']
# Out:
# 0      1
# 1      2
# 2      3
# 3    NAN
# Name: col1, dtype: object
# 0      1
# 1      2
# 2      3
# 3    NAN
# Name: col1, dtype: object

# %%
#Combining multiple sources in pandas
#pd.concat() for Stacking or Appending:
import pandas as pd
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'Name': ['Charlie', 'David'], 'Age': [35, 40]})
combined_df =pd.concat([df1,df2],ignore_index=True)
combined_df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
combined_df = pd.concat([df1, df2], axis=1)
combined_df
# Out:
#     Name  Age     Name  Age
# 0  Alice   25  Charlie   35
# 1    Bob   30    David   40

# %%
#combined_df = pd.concat([df1, df2], axis=1)
df_customers = pd.DataFrame({'CustomerID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df_orders = pd.DataFrame({'OrderID': [101, 102, 103], 'CustomerID': [1, 3, 2], 'Amount': [100, 150, 200]})

# %%
combined_df=pd.merge(df_orders,df_customers,on='CustomerID')
combined_df
# Out:
#    OrderID  CustomerID  Amount     Name
# 0      101           1     100    Alice
# 1      102           3     150  Charlie
# 2      103           2     200      Bob

# %%
df_a = pd.DataFrame({'Value_A': [10, 20]}, index=['X', 'Y'])
df_b = pd.DataFrame({'Value_B': [30, 40]}, index=['X', 'Z'])
combined_df=df_a.join(df_b,how='outer')
combined_df
# Out:
#    Value_A  Value_B
# X     10.0     30.0
# Y     20.0      NaN
# Z      NaN     40.0

# %%
#datetime handling
import pandas as pd
date_str = '2023-10-26 14:30:00'
obj=pd.to_datetime(date_str)
obj
# Out:
# Timestamp('2023-10-26 14:30:00')

# %%
date_list = ['2023-01-01', '2023-01-02', '2023-01-03']
dt_index = pd.to_datetime(date_list)

# %%
dt_index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03'], dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame({'date_col': pd.to_datetime(['2024-07-23 10:00', '2024-07-24 11:30'])})
df['year'] = df['date_col'].dt.year
df['day_of_week'] = df['date_col'].dt.day_name()
df['year']
# Out:
# 0    2024
# 1    2024
# Name: year, dtype: int32

# %%
df['day_of_week']
# Out:
# 0      Tuesday
# 1    Wednesday
# Name: day_of_week, dtype: object

# %%
data=pd.DataFrame({'ME':['2023-01-01', '2023-02-02','2023-03-03', '2023-04-04','2023-05-05'],
                   'Value':[100,200,220,180,120]
                   })
data['ME']=pd.to_datetime(data['ME'])
data.set_index('ME',inplace=True)

monthly_data = data.resample('ME')['Value'].first()
print(monthly_data)
# Out:
# ME
# 2023-01-31    100
# 2023-02-28    200
# 2023-03-31    220
# 2023-04-30    180
# 2023-05-31    120
# Freq: ME, Name: Value, dtype: int64

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# ---------- 1. Customers ----------
customer_ids = [f'CUST{100+i}' for i in range(15)]
customers = pd.DataFrame({
    'customer_id': customer_ids,
    'customer_name': [f'Customer_{i}' for i in range(len(customer_ids))],
    'country': random.choices(['USA', 'UK', 'Germany', 'India'], k=len(customer_ids))
})
customers.to_csv("/content/customers.csv", index=False)

# ---------- 2. Products ----------
product_ids = [f'PROD{200+i}' for i in range(10)]
products = pd.DataFrame({
    'product_id': product_ids,
    'product_name': [f'Product_{i}' for i in range(len(product_ids))],
    'price': [random.randint(20, 200) for _ in range(len(product_ids))]
})
products.to_csv("/content/products.csv", index=False)

# ---------- 3. Orders (simulate realistic purchases) ----------
orders = []

def random_date():
    start = datetime(2025, 7, 1)
    end = datetime(2025, 7, 20)
    return (start + timedelta(days=random.randint(0, (end - start).days))).strftime("%Y-%m-%d")

for i in range(60):  # 60 orders to simulate multiple purchases
    customer = random.choice(customer_ids)
    product = random.choice(product_ids)
    order = {
        'order_id': f'ORD{i+1:04}',
        'customer_id': customer,
        'product_id': product,
        'quantity': random.randint(1, 5),
        'order_date': random_date()
    }
    orders.append(order)

orders_df = pd.DataFrame(orders)
orders_df.to_csv("/content/orders.csv", index=False)
